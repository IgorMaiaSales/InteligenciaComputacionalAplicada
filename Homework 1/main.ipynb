# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

plt.style.use('ggplot')

df = pd.read_csv('abalone.csv')

fig, axs = plt.subplots(2, 4, figsize=[13, 5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7ebf26f54ba> in <module>
#       5 plt.style.use('ggplot')
#       6
# ----> 7 filename = os.path.join(os.path.dirname(__file__), 'abalone.csv')
#       8 df = pd.read_csv(filename)
#       9
#
# NameError: name '__file__' is not defined

# %%
def unconditional_mono_variate(data, subp):
    print(data.name, ':', sep='')
    print("Média:", data.mean())
    print("Desvio padrão:", data.std())
    print("Assimetria:", data.skew())
    subp.hist(data, alpha=0.5)
    subp.set(xlabel=data.name)

# %%
unconditional_mono_variate(df["Length"], axs[0, 0])
# Out:
# Length:
# Média: 0.5239920995930094
# Desvio padrão: 0.12009291256479956
# Assimetria: -0.639873268981801

# %%
unconditional_mono_variate(df["Diameter"], axs[0, 1])
fig.show()
# Out:
# Diameter:
# Média: 0.40788125448886764
# Desvio padrão: 0.09923986613365945
# Assimetria: -0.6091981423290918

# %%
unconditional_mono_variate(df["Height"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7b9865ecfe44> in <module>
# ----> 1 unconditional_mono_variate(df["Height"])
#
# TypeError: unconditional_mono_variate() missing 1 required positional argument: 'subp'

# %%
unconditional_mono_variate(df["Whole weight"])
# Out:
# Média: 0.8287421594445774
# Desvio padrão: 0.4903890182309977
# Assimetria: 0.5309585632523087

# %%
unconditional_mono_variate(df["Shucked weight"])
# Out:
# Média: 0.35936748862820206
# Desvio padrão: 0.22196294903322014
# Assimetria: 0.7190979217612694

# %%
unconditional_mono_variate(df["Viscera weight"])
# Out:
# Média: 0.18059360785252573
# Desvio padrão: 0.10961425025968446
# Assimetria: 0.5918521514155075

# %%
unconditional_mono_variate(df["Shell weight"])
# Out:
# Média: 0.23883085946851804
# Desvio padrão: 0.1392026695223861
# Assimetria: 0.6209268251392077

# %%
unconditional_mono_variate(df["Rings"])
# Out:
# Média: 9.933684462532918
# Desvio padrão: 3.2241690320681284
# Assimetria: 1.114101898355677
